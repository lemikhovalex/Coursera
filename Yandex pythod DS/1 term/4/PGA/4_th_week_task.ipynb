# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import scipy
import statistics
import math
# %matplotlib inline

# %%
lam = 2

# %%
exp_rv = sts.expon(lam) # выбрал распределение
sample = exp_rv.rvs(1000) # сделал выборку
x = np.linspace(0,6,1000)
pdf = exp_rv.pdf(x) # построил функцию распределения

# %%
plt.hist(sample, normed=True)
plt.plot(x, pdf, label='dist dencity for exp')
plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper right')
plt.show() # построил график функции распределения и гистограму
# Out:
# /home/lemikhovalex/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# For this distribution Expectation and Variance are defined by the only feature $\lambda$ as lam

# %% [markdown]
# $\mathbb{E} = \lambda ^-1$, $\mathbb{D} = \lambda ^-2$

# %%
lam = 2
exp_rv = sts.expon(lam)

# %%
ns = [5, 10, 50]
N = 1000 
avg_n = [] # список для средних

for n in ns:
    for i in range(N):
        sample = exp_rv.rvs(n) #получили выборку
        avg_n.append(statistics.mean(sample)) # взяли среднее
    plt.hist(avg_n, normed=True) # добавили среднее
    print("E = 1, D = 1, n = %d" %n) # указал мат ожидание и дисперсию
    norm_rv = sts.norm(1.0, scipy.sqrt(1.0/n)) 
    x = np.linspace(0,6,1000)
    norm_pdf = norm_rv.pdf(x) 
    plt.plot(x, norm_pdf, label='dist dencity for exp')# построил функцию распределения
    
    plt.ylabel('$average$')
    plt.xlabel('$x$')
    plt.show()
    avg_n = [] # обновил массив
# Out:
# E = 1, D = 1, n = 5
# /home/lemikhovalex/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   if __name__ == '__main__':
# E = 1, D = 1, n = 10
# E = 1, D = 1, n = 50

# %% [markdown]
# С ростом $n$ увеличивается точность

# %%
p = 0.625
n = 40
print(- scipy.sqrt(p*(1-p)/n) * 2 + 0.625)

print(+ scipy.sqrt(p*(1-p)/n) * 2 + 0.625)
# Out:
# 0.4719068910760514
# 0.7780931089239487

# %%
l = 3
p = 1
for i in range(5):
    p = p - 3.0**i/(scipy.math.factorial(i)*1.0)* scipy.math.exp(-l)
print(p)
# Out:
# 0.18473675547622792
