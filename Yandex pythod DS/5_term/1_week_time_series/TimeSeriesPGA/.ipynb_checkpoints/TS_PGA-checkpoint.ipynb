# %%
# %pylab inline
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import warnings
from itertools import product

def invboxcox(y,lmbda):
    if lmbda == 0:
        return(np.exp(y))
    else:
        return(np.exp(np.log(lmbda*y+1)/lmbda))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# c:\users\pc\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# c:\users\pc\appdata\local\programs\python\python38\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['product']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# Скачаем данные

# %%
wage = pd.read_csv('WAG_C_M.csv' ,';', index_col=['month'] , parse_dates=['month'], dayfirst=True)

# %%
wage.head()
# Out:
#             WAG_C_M
# month
# 1993-01-01     15.3
# 1993-02-01     19.1
# 1993-03-01     23.6
# 1993-04-01     30.6
# 1993-05-01     37.5

# %% [markdown]
# # 1 Визуальный анализ ряда

# %%
plt.figure(figsize(15,7))
plt.plot(wage)
plt.ylabel('Wage')
plt.xlabel('Date')
plt.title('Wage in Russia')
plt.show()

# %% [markdown]
# Смотрим на картинку и сразу можем сказать:
# - Есть тренд
# - Тренд не линейный, возможно нужен Бокс-Кокс
# - Дисперсия не стационарна
# - Есть сезоннось, новогодние премии

# %% [markdown]
# Посмотрик, на то какие разности будем смотреть

# %% [markdown]
# # 3 Выбор порядка дифференцирования

# %%
sm.graphics.tsa.plot_acf(wage['WAG_C_M'].values.squeeze(), lags=50)

# %% [markdown]
# # 2 Стабилизация дисперсии (при необходимости)
# И прочее

# %% [markdown]
# Ну да, годовая сезонность есть. Даже двух-годичная. Пока посмотрим на годовую

# %%
wage['WAG_C_M_diff'] = wage['WAG_C_M'] - wage['WAG_C_M'].shift(1)
plt.figure(figsize(15,7))
plt.plot(wage['WAG_C_M_diff'])
plt.ylabel('Wage diff(1)')
plt.xlabel('Date')
plt.title('Wage in Russia, diff = 1')
plt.show()

# %% [markdown]
# Ну да, один раз продифференцировали - избавились от тренда

# %%
wage['WAG_C_M_diff'] = wage['WAG_C_M'] - wage['WAG_C_M'].shift(1)
wage['WAG_C_M_diff_12'] = wage['WAG_C_M_diff'] - wage['WAG_C_M_diff'].shift(12)
plt.figure(figsize(15,7))
plt.plot(wage['WAG_C_M_diff_12'])
plt.ylabel('Wage diff(12)')
plt.xlabel('Date')
plt.title('Wage in Russia, diff = 1, 12')
plt.show()

# %% [markdown]
# От сезонности избавиться получилось, Бокс-Кокс поможет избавится от Меняющейся дисперсии

# %%
wage['WAG_C_M_box'], lmbda = stats.boxcox(wage['WAG_C_M'])
wage['WAG_C_M_diff'] = wage['WAG_C_M_box'] - wage['WAG_C_M_box'].shift(1)
wage['WAG_C_M_diff_12'] = wage['WAG_C_M_diff'] - wage['WAG_C_M_diff'].shift(12)
plt.figure(figsize(15,7))
plt.plot(wage['WAG_C_M_diff_12'])
plt.ylabel('Wage diff(12)')
plt.xlabel('Date')
plt.title('Wage in Russia, diff = 1, 12')
plt.show()

# %% [markdown]
# Ай красота, настоящий шум! А какого мнения про это мистер Дики и господин Фуллер?

# %%
wage.dropna(inplace=True)
print("Оптимальный параметр преобразования Бокса-Кокса: %f" % lmbda)
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(wage['WAG_C_M_diff_12'])[1])
# Out:
# Оптимальный параметр преобразования Бокса-Кокса: 0.263202
# Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# Согласны

# %% [markdown]
# # 4 Выбор начальных приближений для p, q, P, Qp,q,P,Q
#
# Такс, теперь смотрим на автокорреляции, частичные автокорреляции чтобы понять, в каком диапозоне подбирать параметры `SARIMA`

# %%
sm.graphics.tsa.plot_acf(wage['WAG_C_M_diff_12'].values.squeeze(), lags=50)

# %% [markdown]
# Ну да, сезонности в один год хватило

# %%
sm.graphics.tsa.plot_pacf(wage['WAG_C_M_diff_12'].values.squeeze(), lags=50)

# %% [markdown]
# Ну тут есть и далёкие выбросы, возьмём по больше, мы же никуда не спешим

# %%
ps = range(0, 10)
d=1
qs = range(0, 10)
Ps = range(0, 2)
D=1
Qs = range(0, 2)

# %%
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 400

# %% [markdown]
# # 5 Обучение и сравнение моделей-кандидатов, выбор победителя
#
# Да, долго, чуть дольше чем кипит чайнк

# %%
# %%time
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')

for param in parameters_list:
    #try except нужен, потому что на некоторых наборах параметров модель не обучается
    try:
        model=sm.tsa.statespace.SARIMAX(wage['WAG_C_M_box'], order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    #выводим параметры, на которых модель не обучается и переходим к следующему набору
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    #сохраняем лучшую модель, aic, параметры
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    
warnings.filterwarnings('default')
# Out:
# Wall time: 10min 28s

# %% [markdown]
# Так, ipykernell судя по всему чтото не так делает и нужно будет [разобраться](https://github.com/ipython/ipykernel/issues/540)

# %%
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
# Out:
#        parameters        aic
# 182  (4, 5, 1, 0) -22.842303
# 222  (5, 5, 1, 0) -22.117246
# 221  (5, 5, 0, 1) -21.928795
# 181  (4, 5, 0, 1) -21.908795
# 189  (4, 7, 0, 1) -21.855541
# c:\users\pc\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # 6 Анализ остатков построенной модели
# при необходимости — её модификация: если остатки получаются смещёнными, прогноз нужно скорректировать на константу; если остатки нестационарны или автокоррелированы, можно попробовать расширить область, в которой подбираются значения p, q, P, Qp,q,P,Q.
#
# Ну всё, есть модель, го предсказывать и анализировать остатки

# %%
plt.figure(figsize(15,8))
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')

ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Критерий Стьюдента: p=%f" % stats.ttest_1samp(best_model.resid[13:], 0)[1])
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])
# Out:
# Критерий Стьюдента: p=0.458506
# Критерий Дики-Фуллера: p=0.000000
# c:\users\pc\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Остатки нормальные, не коррелированы
#
# # Прогноз

# %%
forecast_len = 36
start = wage.shape[0]
# Out:
# c:\users\pc\appdata\local\programs\python\python38\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # 7 Прогнозирование с помощью финальной модели

# %%
wage2 = wage[['WAG_C_M']]
date_list = [datetime.datetime.strptime("2016-08-01", "%Y-%m-%d") + relativedelta(months=x) for x in range(0, forecast_len)]
future = pd.DataFrame(index=date_list, columns= wage2.columns)
wage2 = pd.concat([wage2, future])
wage2['forecast'] = invboxcox(best_model.predict(start=start, end=start + forecast_len - 1), lmbda)

plt.figure(figsize(15,7))
wage2['WAG_C_M'].plot()
wage2['forecast'].plot(color='r')
plt.ylabel('Wage')
pylab.show()
